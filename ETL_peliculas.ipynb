# %% [markdown]
# ## ETL y EDA

# %% [markdown]
# ## #Problematica:
# - Crea una tabla en SQL con el número de ratings y la media del rating por cada película
# - Puedes crearnos una tabla SQL para que la podamos consultar

# %%
import pandas as pd
import numpy as np
import sql

# %% [markdown]
# ## #Extract
# - Importamos los datos

# %%
#Exporamos los resultados:
movie = pd.read_csv('movie.csv')
rating = pd.read_csv('rating.csv')

# %% [markdown]
# ## #Empezamos hacer la visualizacion de los datos:

# %%
movie.count()
# Out:
# movieId    27278
# title      27278
# genres     27278
# dtype: int64

# %%
rating.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %% [markdown]
# ## #Normalizamos la base de datos: Transform
# - new table = ratings and media rating for movie
# - new table = from
# - Crea una tabla en SQL con el número de ratings y la media del rating por cada película
# - Puedes crearnos una tabla SQL para que la podamos consultar

# %%
#Scamos la columnas inncesarias
new_table = rating.drop(columns=['timestamp', 'userId','movieId'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 #Scamos la columnas inncesarias
# ----> 2 new_table = rating.drop(columns=['timestamp', 'userId','movieId'])
#
# File c:\Users\j0rge\Desktop\ETL\venv\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\j0rge\Desktop\ETL\venv\lib\site-packages\pandas\core\frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
#    5257     errors: IgnoreRaise = "raise",
#    5258 ) -> DataFrame | None:
#    5259     """
#    5260     Drop specified labels from rows or columns.
#    5261
#    (...)
#    5394             weight  1.0     0.8
#    5395     """
# -> 5396     return super().drop(
#    5397         labels=labels,
#    5398         axis=axis,
#    5399         index=index,
#    5400         columns=columns,
#    5401         level=level,
#    5402         inplace=inplace,
#    5403         errors=errors,
#    5404     )
#
# File c:\Users\j0rge\Desktop\ETL\venv\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\j0rge\Desktop\ETL\venv\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File c:\Users\j0rge\Desktop\ETL\venv\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File c:\Users\j0rge\Desktop\ETL\venv\lib\site-packages\pandas\core\indexes\base.py:6977, in Index.drop(self, labels, errors)
#    6975 if mask.any():
#    6976     if errors != "ignore":
# -> 6977         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6978     indexer = indexer[~mask]
#    6979 return self.delete(indexer)
#
# KeyError: "['timestamp', 'userId', 'movieId'] not found in axis"

# %%
#empezamos a unir las columnas con movie
new_table = pd.concat([new_table, movie], axis=1)

# %%
#Emepezamos a sacar los valores Nan
new_table.iloc[27277:]
# Out:
#           rating   movieId             title                    genres
# 27277        4.0  131262.0  Innocence (2014)  Adventure|Fantasy|Horror
# 27278        4.0       NaN               NaN                       NaN
# 27279        3.5       NaN               NaN                       NaN
# 27280        5.0       NaN               NaN                       NaN
# 27281        3.5       NaN               NaN                       NaN
# ...          ...       ...               ...                       ...
# 20000258     4.5       NaN               NaN                       NaN
# 20000259     4.5       NaN               NaN                       NaN
# 20000260     3.0       NaN               NaN                       NaN
# 20000261     5.0       NaN               NaN                       NaN
# 20000262     2.5       NaN               NaN                       NaN
#
# [19972986 rows x 4 columns]

# %%
#Empezamos a sacar los datos que no vayamos a necesitar:
table = new_table.dropna()

# %%
table.head(27279)
# Out:
#        rating   movieId                               title  \
# 0         3.5       1.0                    Toy Story (1995)
# 1         3.5       2.0                      Jumanji (1995)
# 2         3.5       3.0             Grumpier Old Men (1995)
# 3         3.5       4.0            Waiting to Exhale (1995)
# 4         3.5       5.0  Father of the Bride Part II (1995)
# ...       ...       ...                                 ...
# 27273     5.0  131254.0        Kein Bund für's Leben (2007)
# 27274     3.5  131256.0       Feuer, Eis & Dosenbier (2002)
# 27275     4.0  131258.0                  The Pirates (2014)
# 27276     4.5  131260.0                 Rentun Ruusu (2001)
# 27277     4.0  131262.0                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 27273                                       Comedy
# 27274                                       Comedy
# 27275                                    Adventure
# 27276                           (no genres listed)
# 27277                     Adventure|Fantasy|Horror
#
# [27278 rows x 4 columns]

# %%
#Obtenemos la media de Rating de la nueva tabla:
table['rating'].median()
# Out:
# 4.0

# %% [markdown]
# ## #Load

# %%
table.to_csv('newtable.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 table.to_csv('newtable.csv')
#
# NameError: name 'table' is not defined
